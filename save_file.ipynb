# %% [markdown]
# # Reading and writing structured data files #9

# %% [markdown]
# ### Json format

# %%
my_group = {
    "name": "vfdv52-Gumanji530",
    "members": [
        {"name": "Jill",
         "age": 26,
         "job": "biologist",
         "connections":{ 
         "friend": ["Zalika"],
         "partner": ["John"]}
         },
        {"name": "Zalika",
         "age": 28,
         "job": "Designer",
         "connections": {
         "friend": ["Jill"]}
         },
        {"name": "John",
         "age": 27,
         "job": "Writer",
         "connections": {
         "partner": ["Jill"]}
         },
        {"name": "Nash",
         "age": 34,
         "job": "Chef",
         "connections": {
         "cousin": ["John"],
         "landlord": ["Zalika"]}
        }
    ]
}

# %%
import json

with open("friend_group.json", "w") as f:
    json.dump(my_group, f, indent=4, sort_keys=True)
    print("Data saved to friend_group.json")

with open("friend_group.json", "r") as f:
    loaded_group = json.load(f)
    print("Data loaded from friend_group.json")
    print(loaded_group)
# Out:
# Data saved to friend_group.json
# Data loaded from friend_group.json
# {'members': [{'age': 26, 'connections': {'friend': ['Zalika'], 'partner': ['John']}, 'job': 'biologist', 'name': 'Jill'}, {'age': 28, 'connections': {'friend': ['Jill']}, 'job': 'Designer', 'name': 'Zalika'}, {'age': 27, 'connections': {'partner': ['Jill']}, 'job': 'Writer', 'name': 'John'}, {'age': 34, 'connections': {'cousin': ['John'], 'landlord': ['Zalika']}, 'job': 'Chef', 'name': 'Nash'}], 'name': 'vfdv52-Gumanji530'}

# %% [markdown]
# ### Yaml

# %%
import yaml

with open("friend_group.yaml", "w") as f:
    yaml.dump(my_group, f)
    print("Data saved to friend_group.yaml")

with open("friend_group.yaml", "r") as f:
    loaded_group = yaml.load(f, Loader=yaml.FullLoader)
    print("Data loaded from friend_group.yaml")
    print(loaded_group)
# Out:
# Data saved to friend_group.yaml
# Data loaded from friend_group.yaml
# {'members': [{'age': 26, 'connections': {'friend': ['Zalika'], 'partner': ['John']}, 'job': 'biologist', 'name': 'Jill'}, {'age': 28, 'connections': {'friend': ['Jill']}, 'job': 'Designer', 'name': 'Zalika'}, {'age': 27, 'connections': {'partner': ['Jill']}, 'job': 'Writer', 'name': 'John'}, {'age': 34, 'connections': {'cousin': ['John'], 'landlord': ['Zalika']}, 'job': 'Chef', 'name': 'Nash'}], 'name': 'vfdv52-Gumanji530'}
